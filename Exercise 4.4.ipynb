# %%
import pandas as pd
import numpy as np
import os

# %%
df_ords=pd.read_csv(r"C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\01. Original Data\orders.csv")

# %% [markdown]
# # Data Wrangling

# %%
df_ords.drop(columns=['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
df_ords['days_since_prior_order'].value_counts(dropna=False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
df_ords['days_since_prior_order'].dtypes
# Out:
# dtype('float64')

# %%
df_ords_mean=df_ords['days_since_prior_order'].mean()

# %%
df_ords_mean
# Out:
# 11.114836226863012

# %%
df_ords['days_since_prior_order'] = df_ords['days_since_prior_order'].fillna(mean_value)

# %% [markdown]
# # Renaming Column

# %%
df_ords.rename(columns={'order_dow':'orders_day_of_week'},inplace=True)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# # Changing a Variable's data type

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_id'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# # Transposing Data

# %%
# importing data set departments.csv

# %%
df_dep=pd.read_csv(r"C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\01. Original Data\departments.csv")

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# transponding df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t=df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#take the first row of df_dep_t for the header
new_header=df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new=df_dep_t[1:]

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#take the data under the header row for a new df
df_dep_t_new=df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#set the header row as the df header
df_dep_t_new.columns=new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t_new.to_csv(r'C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\02. Prepared Data\departments_wrangled.csv')

# %% [markdown]
# # Data Dictionaries

# %%
data_dict=df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods=pd.read_csv(r"C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\01. Original Data\products.csv")

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# # Subsetting

# %%
df_snacks=df_prods[df_prods['department_id']==19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks=df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_2= df_prods.loc[df_prods['department_id']==19]

# %% [markdown]
# # Exporting Dataframes

# %%
df_ords.to_csv(r'C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\02. Prepared Data\orders_wrangled.csv')

# %%
df_ords
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ords.head()
# Out:
#   order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329        1    prior             1                   2
# 1  2398795        1    prior             2                   3
# 2   473747        1    prior             3                   3
# 3  2254736        1    prior             4                   4
# 4   431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# # Direction 1

# %%
# Created.

# %% [markdown]
# # Direction 2

# %%
# Created.

# %% [markdown]
# # Direction 3

# %%
# Created.

# %% [markdown]
# # Direction 4

# %%
# Find the frequency of orders by hour
order_count_by_hour = df_ords['order_hour_of_day'].value_counts().sort_index()

# %%
# Display the busiest hour
busiest_hour = order_count_by_hour.idxmax()
print(f'The busiest hour for placing orders is: {busiest_hour}:00')
# Out:
# The busiest hour for placing orders is: 10:00

# %%
# Print the frequency of orders by hour
print("\nOrder frequency by hour:")
print(order_count_by_hour)
# Out:
# Order frequency by hour:
# order_hour_of_day
# 0      22758
# 1      12398
# 2       7539
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# Name: count, dtype: int64

# %% [markdown]
# # Direction 5

# %%
df_prods[df_prods['department_id']==4]
# Out:
#        product_id                                      product_name  aisle_id  \
# 30             31                                White Pearl Onions       123
# 42             43                               Organic Clementines       123
# 44             45                                 European Cucumber        83
# 65             66                         European Style Spring Mix       123
# 88             89                    Yogurt Fruit Dip Sliced Apples       123
# ...           ...                                               ...       ...
# 49582       49578                                Black Garlic Bulbs       123
# 49623       49619                                        Opo Squash        83
# 49639       49635  Baby Food Blueberry, Parsnip & Buckwheat Stage 2        83
# 49661       49657                                 Cabernet Tomatoes        83
# 49687       49683                                    Cucumber Kirby        83
#
#        department_id  prices
# ...

# %%
df_produce=df_prods[df_prods['department_id']==4]

# %%
df_produce
# Out:
#        product_id                                      product_name  aisle_id  \
# 30             31                                White Pearl Onions       123
# 42             43                               Organic Clementines       123
# 44             45                                 European Cucumber        83
# 65             66                         European Style Spring Mix       123
# 88             89                    Yogurt Fruit Dip Sliced Apples       123
# ...           ...                                               ...       ...
# 49582       49578                                Black Garlic Bulbs       123
# 49623       49619                                        Opo Squash        83
# 49639       49635  Baby Food Blueberry, Parsnip & Buckwheat Stage 2        83
# 49661       49657                                 Cabernet Tomatoes        83
# 49687       49683                                    Cucumber Kirby        83
#
#        department_id  prices
# ...

# %% [markdown]
# # Direction 6

# %%
df_breakfast_items=df_prods[df_prods['department_id'] == 14]

# %%
df_breakfast_items
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# # Direction 7

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
#department id of alcohol=5
#department id of deli=20
#department id of beverages=7
#department id of meat seafood=12

# %%
df_alcohol=df_prods[df_prods['department_id'] == 5]

# %%
df_alcohol
# Out:
#        product_id                               product_name  aisle_id  \
# 51             52                        Mirabelle Brut Rose       134
# 118           119                     Chardonnay Paso Robles        62
# 149           150                                  Brut Rosé       134
# 233           234                          Tennessee Whiskey       124
# 248           249             Pinot Grigio, California, 2010        62
# ...           ...                                        ...       ...
# 49548       49544                    Cabernet Sauvignon Wine        28
# 49566       49562              Blanc De Noirs Sparkling Wine       134
# 49610       49606                        Organic Natural Red        28
# 49665       49661                                      Porto       134
# 49688       49684  Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# 51                 5    14.4
# 118                5     5.5
# ...

# %%
df_deli=df_prods[df_prods['department_id'] == 20]

# %%
df_deli
# Out:
#        product_id                                   product_name  aisle_id  \
# 48             49  Vegetarian Grain Meat Sausages Italian - 4 CT        14
# 61             62        Premium Deli Oven Roasted Turkey Breast        96
# 73             74                Artisan Chick'n & Apple Sausage        14
# 84             85                           Soppressata Piccante        96
# 108           109                         Grape Leaf Hummus Wrap        13
# ...           ...                                            ...       ...
# 49558       49554                          Roasted Garlic Hommus        67
# 49564       49560    Selects Natural Slow Roasted Chicken Breast        96
# 49585       49581                   Pinto Bean and Cheese Pupusa        13
# 49609       49605                     Classic Hummus Family Size        67
# 49642       49638           Organic Superfirm Vacuum Packed Tofu        14
#
#        department_id  prices
# 48                20    10.1
# ...

# %%
df_beverages=df_prods[df_prods['department_id'] == 7]

# %%
df_beverages
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 19             20  Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# ...           ...                                             ...       ...
# 49659       49655                                     Apple Cider        98
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
#
#        department_id  prices
# ...

# %%
df_meat_seafood=df_prods[df_prods['department_id'] == 12]

# %%
df_meat_seafood
# Out:
#        product_id                                       product_name  \
# 16             17                                  Rendered Duck Fat
# 22             23                             Organic Turkey Burgers
# 34             35     Italian Herb Porcini Mushrooms Chicken Sausage
# 39             40  Beef Hot Links Beef Smoked Sausage With Chile ...
# 83             84                                         Lamb Shank
# ...           ...                                                ...
# 49425       49421                                   Salame, Peppered
# 49440       49436                              Imitation Crab Flakes
# 49509       49505                                Hot Italian Sausage
# 49655       49651                                       Beef Brisket
# 49674       49670                                Beef Summer Sausage
#
#        aisle_id  department_id  prices
# 16           35             12    17.1
# 22           49             12     8.2
# ...

# %% [markdown]
# # Direction 8

# %%
#  The last data frame I created is df_meat_seafood with 907 rows.

# %% [markdown]
# # Direction 9

# %%
df_ords
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329        1    prior             1                   2
# 1        2398795        1    prior             2                   3
# 2         473747        1    prior             3                   3
# 3        2254736        1    prior             4                   4
# 4         431534        1    prior             5                   4
# ...          ...      ...      ...           ...                 ...
# 3421078  2266710   206209    prior            10                   5
# 3421079  1854736   206209    prior            11                   4
# 3421080   626363   206209    prior            12                   1
# 3421081  2977660   206209    prior            13                   1
# 3421082   272231   206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
df_user_1 = df_ords.loc[df_ords['user_id'] == 1]

# %%
df_user_1
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
# 5   3367565        1    prior             6                   2
# 6    550135        1    prior             7                   1
# 7   3108588        1    prior             8                   1
# 8   2295261        1    prior             9                   1
# 9   2550362        1    prior            10                   4
# 10  1187899        1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
df_user_1.to_csv(r'C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\02. Prepared Data\user_1_info.csv')

# %% [markdown]
# # Direction 10

# %%
# 1. Total number of orders
total_orders=df_user_1['order_id'].nunique() 
print(f'Total number of orders placed by user 1: {total_orders}')
# Out:
# Total number of orders placed by user 1: 11

# %%
# 2. Average days between orders
average_days_between_orders = df_user_1['days_since_prior_order'].mean()
print(f"Average days between orders for user 1: {average_days_between_orders:.2f} days")
# Out:
# Average days between orders for user 1: 19.00 days

# %%
# 3. Order frequency distribution by day of the week
order_day_distribution = df_user_1['orders_day_of_week'].value_counts().sort_index()
print("\nOrder frequency by day of the week for user 1:")
print(order_day_distribution)
# Out:
# Order frequency by day of the week for user 1:
# orders_day_of_week
# 1    3
# 2    2
# 3    2
# 4    4
# Name: count, dtype: int64

# %%
# 4. Order frequency distribution by hour of the day
order_hour_distribution = df_user_1['order_hour_of_day'].value_counts().sort_index()
print("\nOrder frequency by hour of the day for user 1:")
print(order_hour_distribution)
# Out:
# Order frequency by hour of the day for user 1:
# order_hour_of_day
# 7     3
# 8     3
# 9     1
# 12    1
# 14    1
# 15    1
# 16    1
# Name: count, dtype: int64

# %%
order_day_distribution.to_csv(r'C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\02. Prepared Data\user_1_order_day_distribution.csv')

# %%
order_hour_distribution.to_csv(r'C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\02. Prepared Data\user_1_order_hour_distribution.csv')

# %% [markdown]
# # Direction 11

# %%
# Checked.

# %% [markdown]
# # Direction 12

# %%
# Exported.

# %% [markdown]
# # Direction 13

# %%
df_dep_t_new.to_csv(r'C:\Users\sojan\Documents\Instacast_Basket_Analysis\02. Data\02. Prepared Data\departments_wrangled.csv')

# %%
# Exported.
